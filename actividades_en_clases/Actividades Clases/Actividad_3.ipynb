# %%
# Importar y leer
import pandas as pd
emisiones = pd.read_csv("Emisiones_CO2.csv", encoding="latin1", sep="|")

# %%
# Selecciona los primeros n elementos
print("Impresión de los primeros 10 registros")
n = 10
emisiones.head(n)
# Out:
# Impresión de los primeros 10 registros
#   Código de país Nombre del país                   Región   Año CO2 (kt)  \
# 0            ABW           Aruba  América Latina y Caribe  1960      NaN
# 1            ABW           Aruba  América Latina y Caribe  1961      NaN
# 2            ABW           Aruba  América Latina y Caribe  1962      NaN
# 3            ABW           Aruba  América Latina y Caribe  1963      NaN
# 4            ABW           Aruba  América Latina y Caribe  1964      NaN
# 5            ABW           Aruba  América Latina y Caribe  1965      NaN
# 6            ABW           Aruba  América Latina y Caribe  1966      NaN
# 7            ABW           Aruba  América Latina y Caribe  1967      NaN
# 8            ABW           Aruba  América Latina y Caribe  1968      NaN
# 9            ABW           Aruba  América Latina y Caribe  1969      NaN
#
#   CO2 per cápita (toneladas métricas)
# 0                                 NaN
# 1                                 NaN
# ...

# %%
# Muestra las dimensiones de la tabla (x, y)
print("Impresión de (# filas, # columnas)")
emisiones.shape

# %%
# El primero solo entrega el tipo de dato
# El segundo entrega el tipo y cantidad de not null
print("Impresión tipos de datos de cada columna")
#emisiones.dtypes
emisiones.info()

# %%
# Muestra los null y los suma (por columna)
print("Impresion de cantidad de valores nulos")
emisiones.isnull().sum()

# %%
# Muestra los duplicados y los suma (por columna)
print("Impresión de cantidad de filas duplicadas")
emisiones.duplicated().sum()

# %%
# Cambiar el tipo de dato de columnas
emisiones["CO2 (kt)"] = pd.to_numeric(emisiones["CO2 (kt)"], errors="coerce")
emisiones["CO2 per cápita (toneladas métricas)"] = pd.to_numeric(emisiones["CO2 per cápita (toneladas métricas)"], errors="coerce")
emisiones.info()

# %%
# Medias, emdianas, etc.
emisiones.describe()

# %%
# Ordena y muestra los primeros 10 registros
emisiones.sort_values("CO2 (kt)", ascending=False).head(10)
